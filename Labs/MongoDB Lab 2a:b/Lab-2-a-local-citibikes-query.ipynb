# %%
'''
MongoDB - Lab 2a
COMP 353
Brian Nguyen
'''

import pymongo
import pprint

# %%
# client=pymongo.MongoClient("mongodb://localhost:27017")
client = pymongo.MongoClient('mongodb+srv://bnguyen3:26049569@mflix.5rqvo.mongodb.net/mflix?retryWrites=true&w=majority')
print(client.citibike)
# Out:
# Database(MongoClient(host=['mflix-shard-00-01.5rqvo.mongodb.net:27017', 'mflix-shard-00-00.5rqvo.mongodb.net:27017', 'mflix-shard-00-02.5rqvo.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-dukxl6-shard-0', ssl=True), 'citibike')

# %%
trips = client.citibike.trips

# %%
# find all trips between 5 and 10 minutes in duration that start at station 279

query = {'start station id': 279, 'tripduration' : {'$gte': 300, '$lte': 600}}

# only return the bikeid, tripduration.  The id is displayed by default.  Suppress it.
projection = {'_id': 0, 'bikeid': 1, 'tripduration': 1}

# %%
# print all of the trips
print(trips.count_documents(query))

for doc in trips.find(query, projection):
    pprint.pprint(doc)
# Out:
# 162
# {'bikeid': 16685, 'tripduration': 404}
# {'bikeid': 17130, 'tripduration': 600}
# {'bikeid': 22562, 'tripduration': 453}
# {'bikeid': 22288, 'tripduration': 430}
# {'bikeid': 19804, 'tripduration': 429}
# {'bikeid': 19962, 'tripduration': 386}
# {'bikeid': 15269, 'tripduration': 529}
# {'bikeid': 22336, 'tripduration': 378}
# {'bikeid': 22417, 'tripduration': 507}
# {'bikeid': 17975, 'tripduration': 537}
# {'bikeid': 19838, 'tripduration': 488}
# {'bikeid': 19093, 'tripduration': 451}
# {'bikeid': 23261, 'tripduration': 327}
# {'bikeid': 23377, 'tripduration': 481}
# {'bikeid': 18936, 'tripduration': 546}
# {'bikeid': 23970, 'tripduration': 455}
# {'bikeid': 24765, 'tripduration': 339}
# {'bikeid': 19656, 'tripduration': 319}
# {'bikeid': 22765, 'tripduration': 416}
# {'bikeid': 23863, 'tripduration': 579}
# {'bikeid': 15269, 'tripduration': 503}
# {'bikeid': 24303, 'tripduration': 459}
# {'bikeid': 23979, 'tripduration': 466}
# {'bikeid': 22133, 'tripduration': 337}
# ...
