# %%
'''
MongoDB - Lab 1b
COMP 353
Brian Nguyen
'''

import pymongo
from pymongo import MongoClient
import pprint

client = MongoClient('mongodb+srv://bnguyen3:26049569@mflix.5rqvo.mongodb.net/mflix?retryWrites=true&w=majority')

print(client.mflix)
# Out:
# Database(MongoClient(host=['mflix-shard-00-01.5rqvo.mongodb.net:27017', 'mflix-shard-00-02.5rqvo.mongodb.net:27017', 'mflix-shard-00-00.5rqvo.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-dukxl6-shard-0', ssl=True), 'mflix')

# %%
# Q1
result = client.mflix.movies_initial.find({'imdbRating': {'$gte': 9}})
pprint.pprint(list(result))
# Out:
# [{'_id': ObjectId('61a1d4ac2ac209802ec7aaaf'),
#   'awards': 'Won 3 Oscars. Another 30 wins & 19 nominations.',
#   'cast': 'Marlon Brando, Al Pacino, James Caan, Richard S. Castellano',
#   'country': 'USA',
#   'director': 'Francis Ford Coppola',
#   'fullplot': 'When the aging head of a famous crime family decides to '
#               'transfer his position to one of his subalterns, a series of '
#               'unfortunate events start happening to the family, and a war '
#               'begins between all the well-known families leading to '
#               'insolence, deportation, murder and revenge, and ends with the '
#               'favorable successor being finally chosen.',
#   'genre': 'Crime, Drama',
#   'imdbID': 68646,
#   'imdbRating': 9.2,
#   'imdbVotes': 1038358,
#   'language': 'English, Italian, Latin',
#   'lastupdated': '2015-09-02 00:08:23.680000000',
#   'metacritic': 100,
#   'plot': 'The aging patriarch of an organized crime dynasty transfers control '
# ...

# %%
client.mflix.movies_initial.find_one()
# Out:
# {'_id': ObjectId('61a1d4a52ac209802ec788ff'),
#  'imdbID': 5,
#  'title': 'Blacksmith Scene',
#  'year': 1893,
#  'rating': 'UNRATED',
#  'runtime': '1 min',
#  'genre': 'Short',
#  'released': '1893-05-09',
#  'director': 'William K.L. Dickson',
#  'writer': '',
#  'cast': 'Charles Kayser, John Ott',
#  'metacritic': '',
#  'imdbRating': 6.2,
#  'imdbVotes': 1189,
#  'poster': '',
#  'plot': 'Three men hammer on an anvil and pass a bottle of beer around.',
#  'fullplot': 'A stationary camera looks at a large anvil with a blacksmith behind it and one on either side. The smith in the middle draws a heated metal rod from the fire, places it on the anvil, and all three begin a rhythmic hammering. After several blows, the metal goes back in the fire. One smith pulls out a bottle of beer, and they each take a swig. Then, out comes the glowing metal and the hammering resumes.',
#  'language': '',
#  'country': 'USA',
#  'awards': '1 win.',
# ...

# %%
# Q2
#client.mflix.movies_initial.find({'director': 'Steven Spielberg'}).count()
print(client.mflix.movies_initial.count_documents({'director': 'Steven Spielberg'}))
# Out:
# 32

# %%
# Q3
pprint.pprint(list(client.mflix.movies_initial.find({'cast': 'Brad Pitt'})))
# Out:
# [{'_id': ObjectId('61a1d4cf2ac209802ec834de'),
#   'awards': '',
#   'cast': 'Brad Pitt',
#   'country': 'USA',
#   'director': 'Robert Zemeckis',
#   'fullplot': 'After falling in love with a French agent during a dangerous '
#               'North African mission, an Allied counter-intelligence agent is '
#               'quietly notified that the woman he has married and had a baby '
#               'with is likely a Nazi spy. While a test is run to confirm if '
#               "she is or isn't, he discovers she is a spy but fails to get his "
#               'family safely out of the country. To protect her family, she '
#               'commits suicide. Years later, he and his daughter finally learn '
#               'the truth.',
#   'genre': 'Drama, Romance, Thriller',
#   'imdbID': 3640424,
#   'imdbRating': '',
#   'imdbVotes': '',
#   'language': '',
#   'lastupdated': '2015-06-08 15:34:10.057000000',
#   'metacritic': '',
#   'plot': 'Plot is unknown.',
#   'poster': '',
# ...

# %%
# Q4
# list(client.mflix.movies_initial.find({'$text': {'$search': 'Brad Pitt'}}))
# list(client.mflix.movies_initial.find({'$text': {'$search': '\'Brad Pitt\''}}))
pprint.pprint(list(client.mflix.movies_initial.find({"cast": "\"Brad Pitt\""})))
client.mflix.movies_initial.count_documents({"cast": "\"Brad Pitt\""})
# Out:
# []
# 0

# %%
client.mflix.movies_initial.count_documents({"cast": {'$regex': 'Brad Pitt'}})
# Out:
# 40

# %%
pprint.pprint(list(client.mflix.movies_initial.find({"cast": {'$regex': 'Brad Pitt'}})))
# Out:
# [{'_id': ObjectId('61a1d4b22ac209802ec7c0af'),
#   'awards': '',
#   'cast': 'Donovan Leitch Jr., Jill Schoelen, Brad Pitt, Roddy McDowall',
#   'country': 'USA',
#   'director': 'Rospo Pallenberg',
#   'fullplot': "High school student Paula Carson's affections are being sought "
#               'after by two of her classmates: Dwight, the "bad boy", and '
#               'Brian, a disturbed young man who has just been released from a '
#               'mental hospital where he was committed following the suspicious '
#               'death of his father. Soon after being released, more murders '
#               'start happening. Is Brian back to his old tricks, or is Dwight '
#               'just trying to eliminate the competition?',
#   'genre': 'Comedy, Crime, Horror',
#   'imdbID': 97136,
#   'imdbRating': 4.1,
#   'imdbVotes': 3105,
#   'language': 'English',
#   'lastupdated': '2015-07-24 00:35:35.850000000',
#   'metacritic': '',
# ...
